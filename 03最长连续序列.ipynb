# %% [markdown]
# 给定一个未排序的整数数组 nums ，找出数字连续的最长序列（不要求序列元素在原数组中连续）的长度。
#
# 请你设计并实现时间复杂度为 O(n) 的算法解决此问题。
#
#
#
# 示例 1：
#
# 输入：nums = [100,4,200,1,3,2]
# 输出：4
# 解释：最长数字连续序列是 [1, 2, 3, 4]。它的长度为 4。
# 示例 2：
#
# 输入：nums = [0,3,7,2,5,8,4,6,0,1]
# 输出：9
# 示例 3：
#
# 输入：nums = [1,0,1,2]
# 输出：3
#
#
# 提示：
#
# 0 <= nums.length <= 105
# -109 <= nums[i] <= 109

# %%
#最优解：
class Solution:
    def longestConsecutive(self, nums: List[int]) -> int:
        # 刚刚一直失败，是因为没有解决nums出现了[1,1,1,2,3]这样重复元素的情况
        #为此，可以利用集合的去重，将list转为set；set(list)->[1,2,3]
        st  = set(nusm)
        ans = 0
        for i in st:
            if i - 1 in st:
                continue
            y = i +1
            while y in st:
                y += 1
            ans = max([ans,y-x])
        # 循环结束后，y-1 是最后一个在哈希集合中的数
 
        return ans
"""
巧妙点：
1.将数组转换为集合，去重
2.用 x、x+1...是否存在于集合之中来判断连续与否
3.如果x-1存在的话，就直接跳过当前的x，直至找到最小的：
4.用连续数字的头和尾相减就是序列长度
3（x），4，5，6，7，8（这里是y-1，因为y=9时，不连续了所以退出了循环）序列长度为y-x
"""

# %%
# 解2:数组排序后,一个一个遍历:
class Solution:
    def longestConsecutive(self, nums: List[int]) -> int:
        li = []
        ans = 1
        nums_sorted = sorted(nums)
        if not nums_sorted:
            return 0

        for i in range(1,len(nums_sorted)):
            if nums_sorted[i] == nums_sorted[i-1]:
                continue
            if nums_sorted[i] - nums_sorted[i-1] == 1:
                ans += 1
            else:
                li.append(ans)
                ans = 1
        li.append(ans)
        return max(li)
    #关键,利用  nums_sorted[i] == nums_sorted[i-1] 来去重
    #在循环结束后,还要将最后的ans加入到li中,因为最后一个连续序列可能是最长的,不然返回不全

# %%
# 错解：
# ----------------------------------------------------------------------------
        # 暴力枚举失败，我这样的逻辑不能满足[0,3,7,2,5,8,4,6,0,1]，一个一个遍历会出现错误，i = 0 ，j会取完12345.。 肯定找不到来连续的
class Solution:
    def longestConsecutive(self, nums: List[int]) -> int:
        nums.sort()
        for i in range(len(nums[:-1])):
            ans = 1
            for j in range(len(nums[i+1:])):
                score = 1
                if nums[j] - nums[i] == 1 and nums[j] != nums[j-1]:
                    score += 1
                else:
                    ans = max(ans,score)
                    
        return ans 

# ----------------------------------------------------------------------------------------------                    

        # #如何找出连续数字？
        # li = []
        # ans = 0
        # # 排序数列
        # nums.sort() #不用找一个新变量来承接排序后的数组，因为 sort() 方法是就地排序，不返回新列表
        # for i in range(len(nums)-1):
        #     if nums[i+1] - nums[i] == 1:
        #         ans += 1
        #     else:
        #         li.append(ans)
        #         ans = 0
        # return max(li)  对于[1,0,1,2]这种，排序后为0112，不能满足题意
        # 集合没有下标索引

# 哈希字典的话，key应该是不一样的，value可变，才好构建字典
