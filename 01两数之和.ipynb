# %% [markdown]
# 给定一个整数数组 nums 和一个整数目标值 target，请你在该数组中找出 和为目标值 target  的那 两个 整数，并返回它们的数组下标。
#
# 你可以假设每种输入只会对应一个答案，并且你不能使用两次相同的元素。
#
# 你可以按任意顺序返回答案。
#
#
#
# 示例 1：
#
# 输入：nums = [2,7,11,15], target = 9
# 输出：[0,1]
# 解释：因为 nums[0] + nums[1] == 9 ，返回 [0, 1] 。
# 示例 2：
#
# 输入：nums = [3,2,4], target = 6
# 输出：[1,2]
# 示例 3：
#
# 输入：nums = [3,3], target = 6
# 输出：[0,1]

# %%
#优化解
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        dic = {}
        # 收集nums下标及元素
        for i,j in enumerate(nums): #j = nums[i]
            val = target - j
            if val in dic:
                return [i,dic[val]]
            dic[j] = i

# %%
# 解法1：字典哈希
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        
        dic = {}
        
        for i in range(len(nums)):
            val = target - nums[i]

            if dic.get(val) != None:
                return [dic[val],i]

            dic[nums[i]] = i

        return []

# %% [markdown]
# ----------------------如何避免重复呢? 先查再存-----------------------------------
# [2,7,11,15]
#
# i = 0 时，dic为空字典，dic.get(val) = None
# 会自动为字典里储值
# 变为{2:0}
#
# i = 1 时，
# val = 9 -nums[1] = 2
# dic.get(2) != None
# 找到了，直接结束，返回下标
# return [dic[2],i]
# [0,1]
#
# ------------------------------------------
#
# 如果是先把所有元素存在一个字典里，这样无法在保证在找元素时排除重复的元素
# nums = [[3,2,4]] target = 6
#         dic = {}
#
#         for i in range(len(nums)):
#             val = target - nums[i]
#             dic[nums[i]] = i
#             if dic.get(val) != None:
#                 return [dic[val],i]
#         return []
#
# i = 0 时
# val = 3
# dic->dic{3:0}
# 查到了dic[3]存在，不等于none
#     return了[0,0]

# %%
#解法2 直接在列表里检索目标值，但是太麻烦，因为创建了很多切片，且新切片的下表会变
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:        
        for i in range(len(nums)):
            val = target - nums[i]
            if val in nums[i+1:len(nums)]:
                idx = nums[i+1:len(nums)].index(val)+1+i
                return [i,idx]
